# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set('poster')

# %%
FS_SCHNORR = {2:1754,
              4:7174,
              8:28969,
              16:117063,
              32:458268,
              64:1797386
             }

PRIO = {2:20,
4:32,
8:55,
16:89,
32:143,
64:233,
128:403,
256:789,
512:1576,
1024:3145,
2048:6277,
4096:12627,
8192:25190,}

POPLAR = {
2:29,
4:44,
8:68,
16:112,
32:167,
64:290,
128:570,
256:1113,
512:2236,
1024:4433,
2048:8984,
4096:17710,
8192:35476,}

# %%
ax = pd.DataFrame([POPLAR, PRIO, FS_SCHNORR], index = ['Poplar', 'Prio', 'Ours']).T.plot(figsize=(20, 6),  style=['+-','o-','.--'])
ax.set_title('Verification Times For Client Data')
ax.set_xlabel('Number of Candidates M')
ax.set_ylabel('Micro-seconds')
ax.set_yscale('log')
